# %%
import pandas as pd
data = pd.read_csv('athlete_events1.csv')

# %%
data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
#data.drop(['NOC'],axis=1,inplace=True)

# %%
data.isna().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9315
# Height     58814
# Weight     61527
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     229959
# dtype: int64

# %%
data.columns
# Out:
# Index(['Sex', 'Age', 'Height', 'Weight', 'Team', 'Games', 'Year', 'Season',
#        'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
data.head(5)
# Out:
#   Sex   Age  Height  Weight            Team        Games  Year  Season  \
# 0   M  24.0   180.0    80.0           China  1992 Summer  1992  Summer
# 1   M  23.0   170.0    60.0           China  2012 Summer  2012  Summer
# 2   M  24.0     NaN     NaN         Denmark  1920 Summer  1920  Summer
# 3   M  34.0     NaN     NaN  Denmark/Sweden  1900 Summer  1900  Summer
# 4   F  21.0   185.0    82.0     Netherlands  1988 Winter  1988  Winter
#
#         City          Sport                             Event Medal
# 0  Barcelona     Basketball       Basketball Men's Basketball   NaN
# 1     London           Judo      Judo Men's Extra-Lightweight   NaN
# 2  Antwerpen       Football           Football Men's Football   NaN
# 3      Paris     Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Gold
# 4    Calgary  Speed Skating  Speed Skating Women's 500 metres   NaN

# %%
data.isna().sum()
# Out:
# Sex            0
# Age         9315
# Height     58814
# Weight     61527
# Team           0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     229959
# dtype: int64

# %%
data['Age'].mean()
# Out:
# 25.454776204227084

# %%
data.fillna({'Age':"25.45", 'Height':"175.33", 'Weight': "70.70"},inplace=True)

# %%
data.isna().sum()
# Out:
# Sex            0
# Age            0
# Height         0
# Weight         0
# Team           0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     229959
# dtype: int64

# %%
data.fillna({'Medal':"No Medal"}, inplace=True)

# %%
data.columns
# Out:
# Index(['Sex', 'Age', 'Height', 'Weight', 'Team', 'Games', 'Year', 'Season',
#        'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
data.drop('ID',axis=1)
# Out:
#                             Name Sex   Age                 Height  \
# 0                      A Dijiang   M  24.0                  180.0
# 1                       A Lamusi   M  23.0                  170.0
# 2            Gunnar Nielsen Aaby   M  24.0  {data.iloc[4].mean()}
# 3           Edgar Lindenau Aabye   M  34.0  {data.iloc[4].mean()}
# 4       Christine Jacoba Aaftink   F  21.0                  185.0
# ...                          ...  ..   ...                    ...
# 271111                Andrzej ya   M  29.0                  179.0
# 271112                  Piotr ya   M  27.0                  176.0
# 271113                  Piotr ya   M  27.0                  176.0
# 271114        Tomasz Ireneusz ya   M  30.0                  185.0
# 271115        Tomasz Ireneusz ya   M  34.0                  185.0
#
#                         Weight            Team  NOC        Games  Year  \
# 0                         80.0           China  CHN  1992 Summer  1992
# ...

# %%
# data.drop(('Name'),axis=1,inplace=True)

# %%
from sklearn.compose import make_column_transformer
import sklearn.preprocessing as ps
standardscaler = ps.StandardScaler()
ordinalencoder = ps.OrdinalEncoder()
transformer = make_column_transformer((ordinalencoder,['Sex', 'Team', 'Games','Season', 'City', 'Sport', 'Event', 'Medal']),(standardscaler,['Height', 'Weight', 'Age', 'Year']))

# %%
data.columns
# Out:
# Index(['Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games', 'Year',
#        'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
pdata=transformer.fit_transform(data)

# %%
from sklearn import decomposition

pca = decomposition.PCA(n_components=2)
data_x = pca.fit_transform(pdata)
data_x
# Out:
# array([[-381.84049409, -209.60050862],
#        [-382.59943741,   29.62101203],
#        [-307.43247302,  -19.7798928 ],
#        ...,
#        [ 227.77825332,  230.3855573 ],
#        [ 229.11461058, -189.35272327],
#        [ 229.11855875, -189.34920099]])

# %%
p
